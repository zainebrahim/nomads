# %%
import sys
import pickle
sys.path.append('./../NeuroDataResource')
from NeuroDataResource import NeuroDataResource
from matplotlib import  pyplot as plt
import numpy as np
from skimage.measure import label

# %%
myToken = pickle.load(open('../NeuroDataResource/data/token.pkl', 'rb'))

# %%
ndr = NeuroDataResource('api.boss.neurodata.io',
                        myToken,
                        'collman',
                        'collman15v2',
                        [{'name': 'PSD95_488', 'dtype': 'uint8'}])

# %%
data = ndr.get_cutout('PSD95_488',
                      [4, 14],
                      [1000, 4000],
                      [1000, 4000])

# %%
for elem in data:
    plt.figure()
    plt.imshow(elem, cmap='gray')
    plt.show()

# %%
def get_cluster_median(labels):
    return

def median_spec_binarize(img, resolution, median)
    cutoff = np.max(img)/2.
    median = get_clister_median(label(img > cutoff))
