# %%
import sys
sys.path.insert(0, "./")
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

## Let's start by importing the image as numpy array

% matplotlib inline

data_dir = "./data/"
img = mpimg.imread(data_dir + "look_at_it.jpg")
imgplot = plt.imshow(img)
print(img.shape)
# Out:
# (400, 600, 3)

# %%
## Takes in data, x, y, z. Where x*y*z = volume of image
## 2d case
Y, X, chans = shape
x_slices = 5
y_slices = 4
y_size = Y/y_slices
x_slices = X/x_slices
print(y_size)
# Out:
# 100

# %%
y_size = Y/29
print(y_size)
# Out:
# 13
